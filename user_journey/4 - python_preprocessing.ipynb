# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from collections import Counter, deque
import itertools

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'D:\DONE PROJECTS\user_journey\3 - user_journey_dumped.csv')
df.head(25)
# Out:
#     user_id  session_id subscription_type  \
# 0      1516     2980231            Annual
# 1      1516     2980248            Annual
# 2      1516     2992252            Annual
# 3      1516     3070491            Annual
# 4      1516     3709807            Annual
# 5      1516     3723132            Annual
# 6      1516     3723365            Annual
# 7      1516     3723382            Annual
# 8      1516     3723427            Annual
# 9      1516     3723483            Annual
# 10     1516     3723508            Annual
# 11     1516     3724778            Annual
# 12     1516     3726160            Annual
# 13     3395     1415870            Annual
# 14     3395     3645805            Annual
# 15     3395     3657408            Annual
# 16     3395     3712148            Annual
# 17     3395     3713857            Annual
# 18    10107      360608            Annual
# 19    10107      360609            Annual
# 20    10107     3653049            Annual
# 21    10107     3655508            Annual
# 22    10107     3655510            Annual
# 23    10107     3655968            Annual
# 24    10107     3656751            Annual
#
#                                          user_journey
# 0   Homepage-Log in-Log in-Log in-Log in-Log in-Lo...
# 1   Other-Sign up-Sign up-Sign up-Sign up-Sign up-...
# 2           Log in-Log in-Log in-Log in-Log in-Log in
# 3   Homepage-Log in-Log in-Log in-Log in-Log in-Lo...
# 4   Log in-Log in-Log in-Log in-Log in-Log in-Log ...
# 5                 Checkout-Checkout-Checkout-Checkout
# 6   Checkout-Checkout-Checkout-Checkout-Checkout-C...
# 7   Checkout-Checkout-Checkout-Checkout-Checkout-C...
# 8                                   Checkout-Checkout
# 9                                       Coupon-Coupon
# 10                Checkout-Checkout-Checkout-Checkout
# 11  Checkout-Checkout-Checkout-Checkout-Checkout-C...
# 12                                  Checkout-Checkout
# 13                                        Other-Other
# 14       Pricing-Sign up-Sign up-Log in-Log in-Log in
# 15                                   Homepage-Pricing
# 16                                   Pricing-Checkout
# 17  Checkout-Checkout-Checkout-Checkout-Checkout-C...
# 18                                  Homepage-Homepage
# 19  Homepage-Homepage-Homepage-Homepage-Homepage-C...
# 20  Homepage-Resources center-Resources center-Res...
# 21  Homepage-Career tracks-Career tracks-Career tr...
# 22  Career tracks-Courses-Career tracks-Career tra...
# 23  Career tracks-Log in-Log in-Log in-Log in-Log ...
# 24  Homepage-Log in-Log in-Log in-Log in-Log in-Lo...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9935 entries, 0 to 9934
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            9935 non-null   int64
#  1   session_id         9935 non-null   int64
#  2   subscription_type  9935 non-null   object
#  3   user_journey       9935 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 310.6+ KB

# %%
def group_by_sessions(data: pd.DataFrame, group_col: str, target_col: str, num_of_sessions: str|int = 'All', count_from: str = 'First') -> pd.DataFrame:
    '''Group user pages visited into a single one big string,
        [num_of_sessions] is the amount of sessions to group from,
        [count_from] is the method to set a direction from where to fetch the amount of sessions, either from the start or the end of user journey'''

    # Validate parameters to match required data types and formats
    if count_from not in {'First', 'Last'}:
        raise ValueError('count_from parameter has to be either "First" or "Last"')
    if not isinstance(num_of_sessions, int) and num_of_sessions != 'All':
        raise ValueError('num_of_sessions parameter has to be either "All" or numeric value') 

    # Make a copy of inputed dataframe
    new_df = data.copy()

    # Return a full user journey string 
    if num_of_sessions == 'All':
        new_df = new_df.groupby(group_col)[target_col].agg(lambda x: (x + '-').sum().strip('-')).reset_index()
        #new_df['user_journey'] = new_df['user_journey'].map(cleanup_session_journey)
        return new_df

    # Return first [num_of_sessions] 
    elif count_from == 'First':
        new_df['row_number'] = new_df.sort_values(['user_id', 'session_id'], ascending=[True, True]).groupby('user_id').cumcount() + 1
        new_df = new_df[new_df['row_number'] <= num_of_sessions]
        new_df = new_df.groupby(group_col)[target_col].agg(lambda x: (x + '-').sum().strip('-')).reset_index()
        #new_df['user_journey'] = new_df['user_journey'].map(cleanup_session_journey)
        return new_df
    
    # Return last [num_of_sessions]
    elif count_from == 'Last':
        new_df['row_number'] = new_df.sort_values(['user_id', 'session_id'], ascending=[True, False]).groupby('user_id').cumcount() + 1
        new_df = new_df[new_df['row_number'] <= num_of_sessions]
        new_df = new_df.groupby(group_col)[target_col].agg(lambda x: (x + '-').sum().strip('-')).reset_index()
        #new_df['user_journey'] = new_df['user_journey'].map(cleanup_session_journey)
        return new_df

# %%
def remove_subsequent_pages(journey: str):
    '''Remove sequence of repeating pages, 
        for example replacing `Homepage-Homepage-Homepage-Login` sequence with `Homepage-Login`'''
    journey: list = journey.split('-')
    new_journey = []
    # Iterate through list of pages visited by user  
    for page in journey:
        # Add first page into the empty new_journey list
        if not new_journey:
            new_journey.append(page)
            continue
        # Append page if it is not equal to the previous added page 
        if page != new_journey[-1]:
            new_journey.append(page)
        # Othervise head to the next iteration
        else:
            continue 
    return '-'.join(new_journey)

# %%
def remove_specific_pages(journey: str, pages_to_remove: list):
    # Ensure that pages to be removed are present as list
    if not isinstance(pages_to_remove, list):
        raise ValueError('The pages to be removed should be presented in the form of a list')
    journey = journey.split('-')
    # Iterate through user_journey and keep only those pages which are not present in pages_to_remove list
    for index, page in enumerate(journey):
        if page in pages_to_remove:
            journey.pop(index)
    return '-'.join(journey)

# %%
def get_users_by_subscription(data: pd.DataFrame, subscription: str) -> pd.DataFrame:
    if subscription not in {'Annual', 'Quarterly', 'Monthly'}:
        raise ValueError('There are only 3 subscription types: Annual, Quarterly, Monthly.')
    
    return data[data['subscription_type'] == subscription]

# %% [markdown]
# ## Make a dataset for future analysis

# %%
df1 = group_by_sessions(df, 'user_id', 'user_journey', num_of_sessions='All', count_from='First')

subscription_types = df.groupby('user_id')['subscription_type'].max().reset_index()
all_subs = pd.merge(df1, subscription_types, on='user_id') # Add subscription types 

all_subs['user_journey'] = all_subs['user_journey'].map(remove_subsequent_pages)
# all_subs['user_journey'] = all_subs['user_journey'].map(lambda x: remove_specific_pages(x, ['Homepage']))
all_subs
# Out:
#       user_id                                       user_journey  \
# 0        1516  Homepage-Log in-Other-Sign up-Log in-Homepage-...
# 1        3395  Other-Pricing-Sign up-Log in-Homepage-Pricing-...
# 2       10107  Homepage-Career tracks-Homepage-Career tracks-...
# 3       11145  Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4       12400  Homepage-Career tracks-Sign up-Log in-Other-Ca...
# ...       ...                                                ...
# 1345   509060                                              Other
# 1346   509061                                             Coupon
# 1347   509085                                             Coupon
# 1348   509095                                              Other
# 1349   509096                                       Other-Coupon
#
#      subscription_type
# 0               Annual
# 1               Annual
# 2               Annual
# 3              Monthly
# 4              Monthly
# ...                ...
# 1345            Annual
# 1346            Annual
# 1347            Annual
# 1348            Annual
# 1349            Annual
#
# [1350 rows x 3 columns]

# %%
annual_subs = get_users_by_subscription(df1, 'Annual')
monthly_subs = get_users_by_subscription(df1, 'Monthly')
quarterly_subs = get_users_by_subscription(df1, 'Quarterly')

# %% [markdown]
# ## Page count is the most fundamental metric; it counts how many times each page can be found in all user journeys.

# %%
def total_page_count(data: pd.DataFrame) -> str:
    page_count = Counter(data['user_journey'].apply(lambda x: x + '-').sum().strip('-').split('-'))
    for i, j in page_count.items():
        print(f"{i}: {j}")

total_page_count(all_subs)
# Out:
# Homepage: 2679
# Log in: 2234
# Other: 1189
# Sign up: 1247
# Checkout: 1351
# Coupon: 720
# Pricing: 1053
# Career tracks: 1070
# Resources center: 546
# Courses: 1087
# Career track certificate: 468
# Instructors: 43
# Course certificate: 212
# Success stories: 49
# Upcoming courses: 110
# About us: 20
# Blog: 20

# %% [markdown]
# ## Page presence is similar to ‘page count’ but counts each page only once if it exists in a journey; it shows how many times each page is part of a journey

# %%
# Almost the same code as before but set() was added to eliminate all duplicate pages from each session journey
def page_presence(data: pd.DataFrame) -> str:
    page_presence = Counter(data['user_journey'].map(lambda x: '-'.join(set(x.split('-')))).apply(lambda x: x + '-').sum().strip('-').split('-')) 
    for i, j in page_presence.items():
        print(f"{i}: {j}")

page_presence(all_subs)
# Out:
# Log in: 756
# Checkout: 821
# Homepage: 843
# Sign up: 738
# Coupon: 606
# Other: 623
# Pricing: 476
# Courses: 453
# Career tracks: 380
# Resources center: 184
# Instructors: 25
# Career track certificate: 228
# Course certificate: 151
# Success stories: 38
# Upcoming courses: 83
# About us: 17
# Blog: 13

# %% [markdown]
# ## Page destination is a metric that shows the most frequent follow-ups after every page. It looks at every page and counts which pages follow next. <br>
# ### It is available to configure the number of pages in a sequence.

# %%
def page_followups(data: pd.DataFrame, sequence_of_pages: int = 2) -> str:
    all_pages = iter(data['user_journey'].map(lambda x: x + '-').sum().strip('-').split('-'))
    
    pages = list()

    dic = {}

    while len(pages) != sequence_of_pages:
        pages.append(next(all_pages))

    dic[tuple(pages)] = dic.setdefault(tuple(pages), 0) + 1

    for current_value in all_pages:
        pages.pop(0)
        pages.append(current_value)
        # Save pairs (previous value, following value) as keys 
        dic[tuple(pages)] = dic.setdefault(tuple(pages), 0) + 1

    string = ' -> '.join(('{}' for _ in range(sequence_of_pages))) + ': {}'
    for key, value in sorted(dic.items(), key=lambda x: (-x[1])): 
        print(string.format(*key, value))


page_followups(all_subs, sequence_of_pages=2)
# Out:
# Homepage -> Log in -> Homepage -> Log in: 382
# Log in -> Homepage -> Log in -> Homepage: 341
# Resources center -> Other -> Resources center -> Other: 248
# Other -> Resources center -> Other -> Resources center: 236
# Log in -> Homepage -> Log in -> Checkout: 122
# Career tracks -> Courses -> Career tracks -> Courses: 122
# Homepage -> Log in -> Checkout -> Homepage: 110
# Courses -> Career tracks -> Courses -> Career tracks: 103
# Homepage -> Career tracks -> Homepage -> Career tracks: 83
# Log in -> Checkout -> Log in -> Checkout: 76
# Log in -> Checkout -> Homepage -> Log in: 65
# Sign up -> Log in -> Homepage -> Log in: 59
# Checkout -> Homepage -> Log in -> Checkout: 58
# Log in -> Checkout -> Other -> Log in: 58
# Pricing -> Checkout -> Pricing -> Checkout: 56
# Homepage -> Log in -> Checkout -> Other: 55
# Career tracks -> Homepage -> Career tracks -> Homepage: 49
# Homepage -> Pricing -> Checkout -> Pricing: 49
# Homepage -> Pricing -> Homepage -> Pricing: 49
# Homepage -> Log in -> Checkout -> Log in: 48
# Log in -> Checkout -> Homepage -> Sign up: 47
# Career track certificate -> Career tracks -> Career track certificate -> Career tracks: 46
# Homepage -> Pricing -> Checkout -> Homepage: 45
# Other -> Log in -> Homepage -> Log in: 45
# Homepage -> Sign up -> Log in -> Checkout: 44
# Other -> Log in -> Other -> Log in: 44
# Sign up -> Log in -> Checkout -> Homepage: 44
# Checkout -> Log in -> Checkout -> Log in: 42
# Homepage -> Sign up -> Log in -> Homepage: 41
# Log in -> Checkout -> Homepage -> Pricing: 39
# Sign up -> Homepage -> Log in -> Homepage: 39
# Log in -> Homepage -> Sign up -> Log in: 38
# Sign up -> Homepage -> Log in -> Checkout: 37
# Log in -> Other -> Log in -> Checkout: 37
# Homepage -> Career tracks -> Courses -> Career tracks: 36
# Log in -> Other -> Log in -> Other: 36
# Checkout -> Pricing -> Checkout -> Pricing: 35
# Checkout -> Homepage -> Log in -> Homepage: 33
# Homepage -> Log in -> Homepage -> Pricing: 33
# Checkout -> Homepage -> Sign up -> Homepage: 32
# Homepage -> Sign up -> Homepage -> Log in: 32
# Log in -> Checkout -> Other -> Homepage: 32
# Homepage -> Log in -> Checkout -> Coupon: 31
# Checkout -> Homepage -> Pricing -> Checkout: 31
# Other -> Homepage -> Log in -> Homepage: 31
# Log in -> Checkout -> Coupon -> Homepage: 30
# Log in -> Homepage -> Log in -> Coupon: 30
# Sign up -> Log in -> Checkout -> Other: 30
# Log in -> Checkout -> Log in -> Homepage: 29
# Homepage -> Log in -> Other -> Log in: 29
# Homepage -> Sign up -> Checkout -> Homepage: 28
# Career tracks -> Career track certificate -> Career tracks -> Career track certificate: 28
# Log in -> Checkout -> Homepage -> Career tracks: 27
# Log in -> Other -> Log in -> Homepage: 27
# Pricing -> Homepage -> Pricing -> Homepage: 27
# Other -> Homepage -> Log in -> Checkout: 26
# Log in -> Sign up -> Log in -> Checkout: 26
# Checkout -> Homepage -> Sign up -> Log in: 25
# Homepage -> Log in -> Coupon -> Homepage: 25
# Sign up -> Log in -> Sign up -> Log in: 25
# Log in -> Homepage -> Pricing -> Checkout: 24
# Homepage -> Sign up -> Homepage -> Pricing: 24
# Pricing -> Checkout -> Homepage -> Log in: 24
# Homepage -> Log in -> Homepage -> Sign up: 24
# Other -> Log in -> Checkout -> Homepage: 24
# Checkout -> Other -> Homepage -> Log in: 23
# Sign up -> Checkout -> Homepage -> Sign up: 23
# Checkout -> Other -> Log in -> Homepage: 23
# Log in -> Homepage -> Log in -> Other: 23
# Sign up -> Log in -> Other -> Log in: 23
# Homepage -> Log in -> Sign up -> Log in: 23
# Homepage -> Courses -> Homepage -> Courses: 23
# Career track certificate -> Career tracks -> Courses -> Career tracks: 22
# Sign up -> Log in -> Homepage -> Sign up: 22
# Log in -> Coupon -> Homepage -> Pricing: 22
# Checkout -> Other -> Log in -> Checkout: 22
# Checkout -> Log in -> Checkout -> Homepage: 21
# Courses -> Sign up -> Log in -> Homepage: 21
# Sign up -> Log in -> Checkout -> Log in: 21
# Courses -> Sign up -> Checkout -> Homepage: 21
# Other -> Log in -> Checkout -> Other: 21
# Pricing -> Checkout -> Homepage -> Pricing: 21
# Log in -> Checkout -> Homepage -> Courses: 20
# Log in -> Other -> Homepage -> Log in: 20
# Log in -> Homepage -> Log in -> Sign up: 20
# Checkout -> Log in -> Homepage -> Log in: 19
# Courses -> Career tracks -> Courses -> Homepage: 19
# Homepage -> Career tracks -> Sign up -> Log in: 18
# Career tracks -> Sign up -> Log in -> Homepage: 18
# Homepage -> Career tracks -> Sign up -> Homepage: 18
# Log in -> Homepage -> Sign up -> Homepage: 18
# Log in -> Homepage -> Pricing -> Homepage: 18
# Checkout -> Homepage -> Sign up -> Checkout: 18
# Checkout -> Homepage -> Career tracks -> Sign up: 17
# Sign up -> Checkout -> Homepage -> Career tracks: 17
# Sign up -> Checkout -> Homepage -> Pricing: 17
# Other -> Log in -> Homepage -> Pricing: 17
# Sign up -> Log in -> Checkout -> Coupon: 17
# Courses -> Sign up -> Log in -> Checkout: 17
# Sign up -> Homepage -> Pricing -> Homepage: 17
# Log in -> Sign up -> Log in -> Sign up: 17
# Sign up -> Log in -> Homepage -> Pricing: 16
# Checkout -> Pricing -> Checkout -> Homepage: 16
# Log in -> Checkout -> Courses -> Sign up: 16
# Homepage -> Pricing -> Homepage -> Career tracks: 16
# Homepage -> Sign up -> Homepage -> Career tracks: 16
# Log in -> Checkout -> Log in -> Sign up: 16
# Courses -> Sign up -> Homepage -> Log in: 16
# Checkout -> Log in -> Checkout -> Other: 16
# Courses -> Homepage -> Courses -> Homepage: 16
# Sign up -> Homepage -> Sign up -> Log in: 16
# Checkout -> Homepage -> Career tracks -> Courses: 16
# Homepage -> Instructors -> Homepage -> Instructors: 16
# Career tracks -> Homepage -> Career tracks -> Sign up: 15
# Coupon -> Homepage -> Log in -> Checkout: 15
# Courses -> Log in -> Homepage -> Log in: 15
# Pricing -> Homepage -> Pricing -> Checkout: 15
# Courses -> Sign up -> Courses -> Sign up: 15
# Career tracks -> Sign up -> Log in -> Checkout: 15
# Other -> Log in -> Checkout -> Log in: 15
# Career tracks -> Courses -> Sign up -> Homepage: 15
# Checkout -> Log in -> Sign up -> Log in: 15
# Coupon -> Homepage -> Pricing -> Checkout: 15
# Log in -> Sign up -> Log in -> Homepage: 15
# Career tracks -> Sign up -> Checkout -> Homepage: 15
# Homepage -> Sign up -> Homepage -> Sign up: 15
# Instructors -> Homepage -> Instructors -> Homepage: 15
# Pricing -> Checkout -> Homepage -> Courses: 14
# Coupon -> Homepage -> Sign up -> Homepage: 14
# Pricing -> Checkout -> Coupon -> Homepage: 14
# Homepage -> Career tracks -> Sign up -> Career tracks: 14
# Log in -> Checkout -> Homepage -> Career track certificate: 14
# Log in -> Coupon -> Other -> Log in: 14
# Log in -> Checkout -> Other -> Coupon: 14
# Log in -> Homepage -> Pricing -> Log in: 14
# Career tracks -> Homepage -> Career tracks -> Courses: 14
# Homepage -> Courses -> Career tracks -> Courses: 14
# Checkout -> Coupon -> Homepage -> Log in: 13
# Homepage -> Pricing -> Sign up -> Homepage: 13
# Homepage -> Career tracks -> Courses -> Sign up: 13
# Log in -> Homepage -> Career tracks -> Homepage: 13
# Career tracks -> Courses -> Homepage -> Career tracks: 13
# Courses -> Homepage -> Career tracks -> Homepage: 13
# Sign up -> Homepage -> Career tracks -> Homepage: 13
# Courses -> Homepage -> Pricing -> Checkout: 13
# Coupon -> Other -> Log in -> Homepage: 13
# Sign up -> Log in -> Coupon -> Homepage: 13
# Homepage -> Log in -> Coupon -> Log in: 13
# Coupon -> Homepage -> Log in -> Homepage: 13
# Coupon -> Homepage -> Pricing -> Homepage: 13
# Checkout -> Other -> Log in -> Other: 13
# Homepage -> Pricing -> Homepage -> Sign up: 13
# Checkout -> Other -> Coupon -> Other: 13
# Career tracks -> Courses -> Career tracks -> Homepage: 13
# Checkout -> Homepage -> Pricing -> Courses: 13
# Other -> Log in -> Coupon -> Homepage: 13
# Homepage -> Courses -> Homepage -> Career tracks: 13
# Coupon -> Homepage -> Courses -> Career tracks: 13
# Sign up -> Checkout -> Homepage -> Courses: 13
# Pricing -> Checkout -> Homepage -> Career tracks: 12
# Checkout -> Homepage -> Career tracks -> Homepage: 12
# Pricing -> Sign up -> Homepage -> Log in: 12
# Checkout -> Coupon -> Homepage -> Pricing: 12
# Homepage -> Log in -> Homepage -> Career tracks: 12
# Coupon -> Homepage -> Courses -> Sign up: 12
# Homepage -> Courses -> Sign up -> Log in: 12
# Homepage -> Courses -> Log in -> Homepage: 12
# Homepage -> Career tracks -> Courses -> Homepage: 12
# Homepage -> Log in -> Homepage -> Courses: 12
# Homepage -> Pricing -> Checkout -> Coupon: 12
# Log in -> Coupon -> Log in -> Checkout: 12
# Homepage -> Pricing -> Homepage -> Courses: 12
# Courses -> Career tracks -> Courses -> Pricing: 12
# Log in -> Coupon -> Homepage -> Sign up: 12
# Checkout -> Homepage -> Courses -> Sign up: 12
# Homepage -> Sign up -> Checkout -> Other: 12
# Homepage -> Career tracks -> Sign up -> Checkout: 12
# Checkout -> Coupon -> Homepage -> Courses: 12
# Log in -> Other -> Sign up -> Log in: 11
# Pricing -> Sign up -> Log in -> Homepage: 11
# Career tracks -> Courses -> Log in -> Homepage: 11
# Checkout -> Homepage -> Courses -> Homepage: 11
# Career tracks -> Homepage -> Sign up -> Homepage: 11
# Pricing -> Checkout -> Homepage -> Sign up: 11
# Sign up -> Homepage -> Pricing -> Checkout: 11
# Other -> Coupon -> Homepage -> Pricing: 11
# Pricing -> Log in -> Homepage -> Log in: 11
# Homepage -> Pricing -> Sign up -> Log in: 11
# Other -> Coupon -> Other -> Homepage: 11
# Coupon -> Homepage -> Career tracks -> Sign up: 11
# Sign up -> Checkout -> Homepage -> Log in: 11
# Homepage -> Sign up -> Coupon -> Homepage: 11
# Homepage -> Pricing -> Homepage -> Log in: 11
# Career tracks -> Courses -> Career tracks -> Sign up: 11
# Courses -> Career tracks -> Courses -> Sign up: 11
# Career tracks -> Sign up -> Career tracks -> Courses: 11
# Courses -> Sign up -> Checkout -> Other: 11
# Coupon -> Homepage -> Sign up -> Checkout: 11
# Log in -> Checkout -> Other -> Other: 11
# Career tracks -> Courses -> Career tracks -> Log in: 10
# Career tracks -> Courses -> Sign up -> Log in: 10
# Log in -> Coupon -> Homepage -> Courses: 10
# Pricing -> Checkout -> Log in -> Checkout: 10
# Pricing -> Homepage -> Career tracks -> Courses: 10
# Sign up -> Homepage -> Pricing -> Sign up: 10
# Log in -> Other -> Coupon -> Homepage: 10
# Career tracks -> Sign up -> Homepage -> Log in: 10
# Sign up -> Homepage -> Log in -> Other: 10
# Career tracks -> Sign up -> Career tracks -> Sign up: 10
# Log in -> Sign up -> Log in -> Other: 10
# Other -> Log in -> Checkout -> Coupon: 10
# Checkout -> Homepage -> Pricing -> Homepage: 10
# Homepage -> Log in -> Other -> Homepage: 10
# Pricing -> Sign up -> Log in -> Checkout: 10
# Sign up -> Checkout -> Coupon -> Homepage: 10
# Log in -> Sign up -> Homepage -> Log in: 10
# Courses -> Homepage -> Career tracks -> Courses: 10
# Checkout -> Log in -> Homepage -> Sign up: 10
# Coupon -> Homepage -> Sign up -> Log in: 10
# Other -> Sign up -> Log in -> Checkout: 10
# Career tracks -> Courses -> Career tracks -> Career track certificate: 10
# Homepage -> Sign up -> Homepage -> Courses: 10
# Other -> Homepage -> Log in -> Other: 10
# Homepage -> Courses -> Sign up -> Homepage: 10
# Sign up -> Log in -> Checkout -> Courses: 10
# Sign up -> Checkout -> Log in -> Checkout: 10
# Log in -> Sign up -> Checkout -> Homepage: 10
# Log in -> Checkout -> Pricing -> Sign up: 9
# Log in -> Checkout -> Pricing -> Checkout: 9
# Pricing -> Sign up -> Homepage -> Sign up: 9
# Sign up -> Homepage -> Sign up -> Checkout: 9
# Career tracks -> Career track certificate -> Career tracks -> Courses: 9
# Log in -> Coupon -> Homepage -> Log in: 9
# Log in -> Homepage -> Career tracks -> Courses: 9
# Pricing -> Checkout -> Pricing -> Courses: 9
# Other -> Coupon -> Other -> Coupon: 9
# Checkout -> Homepage -> Career tracks -> Pricing: 9
# Homepage -> Career track certificate -> Career tracks -> Courses: 9
# Other -> Log in -> Homepage -> Sign up: 9
# Homepage -> Pricing -> Sign up -> Checkout: 9
# Pricing -> Sign up -> Checkout -> Homepage: 9
# Coupon -> Log in -> Coupon -> Homepage: 9
# Log in -> Checkout -> Log in -> Other: 9
# Pricing -> Checkout -> Pricing -> Log in: 9
# Log in -> Coupon -> Homepage -> Career tracks: 9
# Homepage -> Career tracks -> Courses -> Log in: 9
# Log in -> Checkout -> Homepage -> Course certificate: 9
# Log in -> Homepage -> Log in -> Courses: 9
# Log in -> Homepage -> Courses -> Homepage: 9
# Career track certificate -> Career tracks -> Sign up -> Log in: 9
# Career tracks -> Sign up -> Log in -> Coupon: 9
# Log in -> Coupon -> Checkout -> Coupon: 9
# Checkout -> Coupon -> Other -> Log in: 9
# Coupon -> Other -> Homepage -> Pricing: 9
# Pricing -> Homepage -> Sign up -> Homepage: 9
# Homepage -> Career tracks -> Pricing -> Checkout: 9
# Coupon -> Log in -> Checkout -> Other: 9
# Homepage -> Pricing -> Log in -> Homepage: 9
# Homepage -> Pricing -> Log in -> Checkout: 9
# Log in -> Courses -> Log in -> Homepage: 9
# Pricing -> Log in -> Pricing -> Log in: 9
# Checkout -> Homepage -> Log in -> Coupon: 9
# Career tracks -> Courses -> Career tracks -> Pricing: 9
# Career track certificate -> Sign up -> Career track certificate -> Career tracks: 9
# Checkout -> Other -> Log in -> Coupon: 9
# Checkout -> Coupon -> Homepage -> Sign up: 9
# Other -> Log in -> Coupon -> Other: 9
# Coupon -> Other -> Log in -> Checkout: 9
# Coupon -> Homepage -> Pricing -> Sign up: 9
# Homepage -> Log in -> Checkout -> Courses: 9
# Homepage -> Log in -> Coupon -> Other: 9
# Log in -> Checkout -> Coupon -> Coupon: 9
# Pricing -> Courses -> Career tracks -> Courses: 9
# Checkout -> Coupon -> Coupon -> Homepage: 9
# Checkout -> Courses -> Sign up -> Checkout: 9
# Log in -> Checkout -> Coupon -> Checkout: 8
# Checkout -> Coupon -> Checkout -> Other: 8
# Checkout -> Pricing -> Checkout -> Other: 8
# Homepage -> Sign up -> Log in -> Other: 8
# Log in -> Checkout -> Coupon -> Log in: 8
# Checkout -> Log in -> Checkout -> Coupon: 8
# Sign up -> Log in -> Homepage -> Career tracks: 8
# Coupon -> Courses -> Sign up -> Checkout: 8
# Homepage -> Log in -> Homepage -> Career track certificate: 8
# Other -> Coupon -> Homepage -> Sign up: 8
# Sign up -> Homepage -> Career tracks -> Sign up: 8
# Homepage -> Career track certificate -> Career tracks -> Sign up: 8
# Career tracks -> Courses -> Homepage -> Log in: 8
# Homepage -> Sign up -> Checkout -> Coupon: 8
# Checkout -> Homepage -> Career track certificate -> Career tracks: 8
# Homepage -> Log in -> Homepage -> Course certificate: 8
# Homepage -> Log in -> Courses -> Log in: 8
# Courses -> Sign up -> Checkout -> Coupon: 8
# Resources center -> Other -> Homepage -> Log in: 8
# Log in -> Other -> Log in -> Coupon: 8
# Career tracks -> Courses -> Homepage -> Courses: 8
# Courses -> Homepage -> Pricing -> Homepage: 8
# Homepage -> Pricing -> Courses -> Career tracks: 8
# Checkout -> Other -> Homepage -> Career tracks: 8
# Coupon -> Other -> Coupon -> Homepage: 8
# Career tracks -> Pricing -> Checkout -> Homepage: 8
# Sign up -> Homepage -> Sign up -> Homepage: 8
# Log in -> Homepage -> Pricing -> Sign up: 8
# Coupon -> Other -> Homepage -> Log in: 8
# Sign up -> Homepage -> Courses -> Homepage: 8
# Sign up -> Checkout -> Other -> Coupon: 8
# Log in -> Checkout -> Coupon -> Other: 8
# Checkout -> Other -> Coupon -> Homepage: 8
# Pricing -> Checkout -> Pricing -> Sign up: 8
# Log in -> Checkout -> Other -> Sign up: 8
# Homepage -> Log in -> Checkout -> Pricing: 8
# Courses -> Career tracks -> Sign up -> Career tracks: 8
# Homepage -> Courses -> Sign up -> Courses: 8
# Checkout -> Homepage -> Courses -> Career tracks: 8
# Homepage -> Courses -> Homepage -> Pricing: 8
# Sign up -> Checkout -> Homepage -> Career track certificate: 8
# Checkout -> Other -> Other -> Homepage: 8
# Sign up -> Checkout -> Other -> Other: 8
# Homepage -> Log in -> Other -> Sign up: 7
# Pricing -> Sign up -> Pricing -> Sign up: 7
# Homepage -> Courses -> Pricing -> Homepage: 7
# Homepage -> Career tracks -> Pricing -> Career tracks: 7
# Homepage -> Career tracks -> Homepage -> Sign up: 7
# Pricing -> Log in -> Homepage -> Pricing: 7
# Career tracks -> Homepage -> Pricing -> Checkout: 7
# Homepage -> Career track certificate -> Sign up -> Career track certificate: 7
# Checkout -> Coupon -> Homepage -> Career tracks: 7
# Homepage -> Career track certificate -> Homepage -> Career track certificate: 7
# Career track certificate -> Career tracks -> Sign up -> Checkout: 7
# Log in -> Homepage -> Courses -> Log in: 7
# Log in -> Resources center -> Other -> Resources center: 7
# Courses -> Log in -> Courses -> Log in: 7
# Sign up -> Homepage -> Log in -> Coupon: 7
# Career tracks -> Sign up -> Career tracks -> Pricing: 7
# Checkout -> Homepage -> Pricing -> Sign up: 7
# Log in -> Checkout -> Coupon -> Sign up: 7
# Log in -> Homepage -> Career tracks -> Sign up: 7
# Coupon -> Homepage -> Log in -> Other: 7
# Career tracks -> Pricing -> Checkout -> Pricing: 7
# Other -> Homepage -> Sign up -> Log in: 7
# Pricing -> Log in -> Checkout -> Homepage: 7
# Other -> Coupon -> Homepage -> Log in: 7
# Career tracks -> Log in -> Homepage -> Career tracks: 7
# Courses -> Career track certificate -> Career tracks -> Courses: 7
# Pricing -> Career tracks -> Courses -> Career tracks: 7
# Courses -> Sign up -> Courses -> Pricing: 7
# Career tracks -> Courses -> Homepage -> Pricing: 7
# Courses -> Sign up -> Homepage -> Career tracks: 7
# Sign up -> Homepage -> Career tracks -> Courses: 7
# Pricing -> Sign up -> Homepage -> Pricing: 7
# Courses -> Log in -> Checkout -> Homepage: 7
# Career tracks -> Homepage -> Log in -> Homepage: 7
# Pricing -> Courses -> Homepage -> Career tracks: 7
# Course certificate -> Career track certificate -> Career tracks -> Career track certificate: 7
# Courses -> Career tracks -> Sign up -> Log in: 7
# Log in -> Sign up -> Log in -> Coupon: 7
# Other -> Courses -> Sign up -> Checkout: 7
# Courses -> Homepage -> Sign up -> Homepage: 7
# Log in -> Homepage -> Sign up -> Checkout: 7
# Pricing -> Checkout -> Coupon -> Other: 7
# Courses -> Sign up -> Homepage -> Sign up: 7
# Courses -> Pricing -> Checkout -> Homepage: 7
# Sign up -> Career track certificate -> Career tracks -> Career track certificate: 7
# Homepage -> Pricing -> Sign up -> Other: 7
# Checkout -> Other -> Sign up -> Log in: 7
# Log in -> Pricing -> Log in -> Pricing: 7
# Checkout -> Coupon -> Other -> Homepage: 7
# Homepage -> Log in -> Checkout -> Sign up: 7
# Log in -> Checkout -> Sign up -> Homepage: 7
# Checkout -> Sign up -> Homepage -> Log in: 7
# Other -> Sign up -> Homepage -> Log in: 7
# Coupon -> Homepage -> Log in -> Coupon: 7
# Coupon -> Coupon -> Homepage -> Courses: 7
# Coupon -> Homepage -> Career tracks -> Homepage: 7
# Career tracks -> Sign up -> Checkout -> Other: 7
# Checkout -> Courses -> Sign up -> Courses: 7
# Coupon -> Coupon -> Homepage -> Pricing: 7
# Sign up -> Log in -> Sign up -> Checkout: 7
# Homepage -> Courses -> Sign up -> Checkout: 7
# Sign up -> Checkout -> Other -> Homepage: 7
# Courses -> Career tracks -> Log in -> Homepage: 6
# Sign up -> Pricing -> Sign up -> Homepage: 6
# Checkout -> Log in -> Checkout -> Pricing: 6
# Homepage -> Career tracks -> Homepage -> Pricing: 6
# Pricing -> Homepage -> Log in -> Checkout: 6
# Coupon -> Log in -> Homepage -> Log in: 6
# Log in -> Checkout -> Pricing -> Log in: 6
# Checkout -> Homepage -> Courses -> Pricing: 6
# Pricing -> Homepage -> Career tracks -> Sign up: 6
# Career tracks -> Sign up -> Homepage -> Pricing: 6
# Career tracks -> Pricing -> Career tracks -> Pricing: 6
# Sign up -> Log in -> Other -> Coupon: 6
# Coupon -> Checkout -> Coupon -> Other: 6
# Pricing -> Sign up -> Pricing -> Checkout: 6
# Pricing -> Career tracks -> Courses -> Homepage: 6
# Homepage -> Pricing -> Career tracks -> Courses: 6
# Coupon -> Other -> Log in -> Coupon: 6
# Career track certificate -> Career tracks -> Homepage -> Sign up: 6
# Course certificate -> Career track certificate -> Career tracks -> Courses: 6
# Homepage -> Pricing -> Checkout -> Log in: 6
# Log in -> Coupon -> Homepage -> Career track certificate: 6
# Coupon -> Homepage -> Career track certificate -> Sign up: 6
# Other -> Log in -> Homepage -> Courses: 6
# Courses -> Log in -> Homepage -> Career tracks: 6
# Checkout -> Pricing -> Checkout -> Coupon: 6
# Pricing -> Log in -> Coupon -> Homepage: 6
# Log in -> Courses -> Log in -> Courses: 6
# Courses -> Homepage -> Log in -> Checkout: 6
# Pricing -> Sign up -> Checkout -> Other: 6
# Sign up -> Log in -> Coupon -> Checkout: 6
# Log in -> Coupon -> Log in -> Coupon: 6
# Coupon -> Checkout -> Homepage -> Log in: 6
# Checkout -> Coupon -> Log in -> Checkout: 6
# Sign up -> Log in -> Coupon -> Other: 6
# Log in -> Pricing -> Log in -> Homepage: 6
# Courses -> Log in -> Sign up -> Log in: 6
# Homepage -> Pricing -> Career tracks -> Sign up: 6
# Log in -> Homepage -> Pricing -> Courses: 6
# Homepage -> Pricing -> Courses -> Pricing: 6
# Homepage -> Career tracks -> Sign up -> Other: 6
# Homepage -> Pricing -> Log in -> Coupon: 6
# Sign up -> Courses -> Sign up -> Checkout: 6
# Checkout -> Career tracks -> Sign up -> Log in: 6
# Resources center -> Other -> Log in -> Checkout: 6
# Homepage -> Pricing -> Courses -> Log in: 6
# Checkout -> Log in -> Other -> Log in: 6
# Courses -> Career tracks -> Homepage -> Pricing: 6
# Pricing -> Checkout -> Pricing -> Career tracks: 6
# Other -> Log in -> Other -> Homepage: 6
# Homepage -> Pricing -> Courses -> Career track certificate: 6
# Checkout -> Homepage -> Career track certificate -> Sign up: 6
# Courses -> Log in -> Homepage -> Pricing: 6
# Pricing -> Homepage -> Log in -> Homepage: 6
# Checkout -> Homepage -> Sign up -> Other: 6
# Resources center -> Other -> Resources center -> Homepage: 6
# Sign up -> Log in -> Sign up -> Homepage: 6
# Career tracks -> Sign up -> Homepage -> Career tracks: 6
# Career tracks -> Courses -> Sign up -> Courses: 6
# Career track certificate -> Log in -> Homepage -> Log in: 6
# Career tracks -> Career track certificate -> Career tracks -> Sign up: 6
# Sign up -> Other -> Homepage -> Log in: 6
# Courses -> Career tracks -> Homepage -> Sign up: 6
# Other -> Log in -> Checkout -> Pricing: 6
# Checkout -> Other -> Homepage -> Pricing: 6
# Career tracks -> Sign up -> Homepage -> Sign up: 6
# Pricing -> Homepage -> Courses -> Log in: 6
# Courses -> Course certificate -> Career track certificate -> Career tracks: 6
# Career track certificate -> Career tracks -> Courses -> Homepage: 6
# Homepage -> Pricing -> Coupon -> Homepage: 6
# Other -> Homepage -> Sign up -> Homepage: 6
# Sign up -> Checkout -> Other -> Log in: 6
# Other -> Resources center -> Other -> Homepage: 6
# Homepage -> Pricing -> Checkout -> Other: 6
# Checkout -> Pricing -> Log in -> Checkout: 6
# Homepage -> Courses -> Career tracks -> Homepage: 6
# Homepage -> Courses -> Career tracks -> Upcoming courses: 6
# Coupon -> Homepage -> Career tracks -> Pricing: 6
# Log in -> Checkout -> Other -> Courses: 6
# Courses -> Sign up -> Courses -> Log in: 6
# Coupon -> Homepage -> Courses -> Homepage: 6
# Pricing -> Courses -> Sign up -> Log in: 6
# Courses -> Career tracks -> Courses -> Upcoming courses: 6
# Homepage -> Log in -> Sign up -> Checkout: 6
# Coupon -> Coupon -> Homepage -> Sign up: 6
# Coupon -> Homepage -> Pricing -> Courses: 6
# Checkout -> Coupon -> Coupon -> Coupon: 6
# Checkout -> Coupon -> Checkout -> Homepage: 6
# Coupon -> Coupon -> Homepage -> Career tracks: 6
# Coupon -> Coupon -> Coupon -> Coupon: 6
# Checkout -> Log in -> Sign up -> Checkout: 6
# Log in -> Sign up -> Checkout -> Log in: 6
# Other -> Sign up -> Log in -> Homepage: 5
# Career tracks -> Log in -> Homepage -> Log in: 5
# Career tracks -> Sign up -> Log in -> Other: 5
# Checkout -> Pricing -> Sign up -> Pricing: 5
# Other -> Homepage -> Pricing -> Homepage: 5
# Homepage -> Career track certificate -> Career tracks -> Career track certificate: 5
# Courses -> Pricing -> Homepage -> Career tracks: 5
# Career tracks -> Homepage -> Career tracks -> Pricing: 5
# Checkout -> Coupon -> Other -> Coupon: 5
# Coupon -> Other -> Coupon -> Other: 5
# Resources center -> Log in -> Other -> Log in: 5
# Career tracks -> Pricing -> Career tracks -> Courses: 5
# Career tracks -> Homepage -> Pricing -> Homepage: 5
# Career tracks -> Courses -> Homepage -> Career track certificate: 5
# Courses -> Homepage -> Career track certificate -> Career tracks: 5
# Career track certificate -> Career tracks -> Courses -> Log in: 5
# Coupon -> Other -> Homepage -> Courses: 5
# Courses -> Sign up -> Log in -> Coupon: 5
# Career tracks -> Pricing -> Checkout -> Coupon: 5
# Coupon -> Homepage -> Career track certificate -> Homepage: 5
# Sign up -> Courses -> Sign up -> Log in: 5
# Sign up -> Log in -> Homepage -> Courses: 5
# Coupon -> Homepage -> Pricing -> Career track certificate: 5
# Other -> Resources center -> Other -> Log in: 5
# Other -> Log in -> Resources center -> Other: 5
# Pricing -> Log in -> Checkout -> Log in: 5
# Checkout -> Other -> Checkout -> Homepage: 5
# Resources center -> Homepage -> Log in -> Homepage: 5
# Other -> Pricing -> Sign up -> Pricing: 5
# Pricing -> Courses -> Career track certificate -> Career tracks: 5
# Career track certificate -> Career tracks -> Sign up -> Career tracks: 5
# Homepage -> Courses -> Homepage -> Log in: 5
# Sign up -> Checkout -> Coupon -> Checkout: 5
# Log in -> Coupon -> Checkout -> Homepage: 5
# Checkout -> Coupon -> Homepage -> Career track certificate: 5
# Log in -> Other -> Resources center -> Other: 5
# Other -> Coupon -> Coupon -> Other: 5
# Homepage -> Log in -> Coupon -> Checkout: 5
# Coupon -> Log in -> Checkout -> Homepage: 5
# Career tracks -> Pricing -> Sign up -> Log in: 5
# Homepage -> Log in -> Pricing -> Log in: 5
# Pricing -> Career tracks -> Sign up -> Career tracks: 5
# Career tracks -> Sign up -> Career tracks -> Homepage: 5
# Pricing -> Homepage -> Pricing -> Log in: 5
# Courses -> Career tracks -> Courses -> Log in: 5
# Checkout -> Homepage -> Pricing -> Log in: 5
# Homepage -> Course certificate -> Sign up -> Course certificate: 5
# Log in -> Homepage -> Course certificate -> Career track certificate: 5
# Checkout -> Homepage -> Log in -> Other: 5
# Other -> Sign up -> Checkout -> Homepage: 5
# Log in -> Sign up -> Checkout -> Coupon: 5
# Resources center -> Other -> Coupon -> Homepage: 5
# Courses -> Homepage -> Courses -> Log in: 5
# Log in -> Checkout -> Log in -> Pricing: 5
# Courses -> Coupon -> Homepage -> Log in: 5
# Homepage -> Career tracks -> Sign up -> Coupon: 5
# Career tracks -> Career track certificate -> Career tracks -> Homepage: 5
# Pricing -> Log in -> Sign up -> Homepage: 5
# Courses -> Career tracks -> Pricing -> Checkout: 5
# Checkout -> Coupon -> Sign up -> Log in: 5
# Courses -> Sign up -> Coupon -> Homepage: 5
# Course certificate -> Courses -> Career tracks -> Courses: 5
# Coupon -> Checkout -> Homepage -> Sign up: 5
# Checkout -> Pricing -> Sign up -> Log in: 5
# Pricing -> Sign up -> Log in -> Sign up: 5
# Courses -> Career tracks -> Sign up -> Homepage: 5
# Homepage -> Career tracks -> Homepage -> Courses: 5
# Courses -> Homepage -> Career tracks -> Sign up: 5
# Homepage -> Sign up -> Other -> Pricing: 5
# Coupon -> Checkout -> Coupon -> Checkout: 5
# Homepage -> Sign up -> Log in -> Coupon: 5
# Log in -> Checkout -> Other -> Career tracks: 5
# Homepage -> Pricing -> Log in -> Sign up: 5
# Pricing -> Checkout -> Pricing -> Homepage: 5
# Pricing -> Homepage -> Pricing -> Career tracks: 5
# Pricing -> Career tracks -> Pricing -> Career tracks: 5
# Courses -> Pricing -> Courses -> Pricing: 5
# Homepage -> Pricing -> Courses -> Homepage: 5
# Homepage -> Resources center -> Other -> Resources center: 5
# Homepage -> Sign up -> Other -> Log in: 5
# Sign up -> Other -> Log in -> Checkout: 5
# Other -> Homepage -> Pricing -> Sign up: 5
# Other -> Coupon -> Homepage -> Courses: 5
# Homepage -> Courses -> Homepage -> Sign up: 5
# Other -> Log in -> Sign up -> Log in: 5
# Sign up -> Coupon -> Homepage -> Sign up: 5
# Pricing -> Courses -> Homepage -> Pricing: 5
# Log in -> Homepage -> Career tracks -> Pricing: 5
# Sign up -> Career tracks -> Courses -> Career tracks: 5
# Log in -> Coupon -> Other -> Coupon: 5
# Courses -> Log in -> Checkout -> Other: 5
# Checkout -> Sign up -> Log in -> Checkout: 5
# Sign up -> Other -> Log in -> Homepage: 5
# Homepage -> Courses -> Log in -> Checkout: 5
# Other -> Other -> Homepage -> Log in: 5
# Coupon -> Log in -> Checkout -> Log in: 5
# Homepage -> Pricing -> Career track certificate -> Sign up: 5
# Pricing -> Sign up -> Pricing -> Log in: 5
# Sign up -> Pricing -> Log in -> Checkout: 5
# Log in -> Checkout -> Other -> Checkout: 5
# Homepage -> Sign up -> Log in -> Sign up: 5
# Sign up -> Log in -> Homepage -> Course certificate: 5
# Homepage -> Courses -> Pricing -> Courses: 5
# Courses -> Pricing -> Courses -> Sign up: 5
# Coupon -> Homepage -> Course certificate -> Sign up: 5
# Courses -> Sign up -> Homepage -> Courses: 5
# Checkout -> Homepage -> Pricing -> Career tracks: 5
# Sign up -> Log in -> Checkout -> Sign up: 5
# Pricing -> Courses -> Pricing -> Courses: 5
# Courses -> Homepage -> Courses -> Career tracks: 5
# Courses -> Sign up -> Homepage -> Pricing: 5
# Homepage -> Courses -> Career tracks -> Sign up: 5
# Courses -> Pricing -> Sign up -> Log in: 5
# Pricing -> Checkout -> Pricing -> Career track certificate: 5
# Career track certificate -> Sign up -> Log in -> Homepage: 5
# Coupon -> Checkout -> Coupon -> Homepage: 5
# Coupon -> Homepage -> Pricing -> Resources center: 5
# Career tracks -> Sign up -> Pricing -> Checkout: 5
# Coupon -> Coupon -> Coupon -> Homepage: 5
# Career tracks -> Sign up -> Checkout -> Coupon: 5
# Sign up -> Checkout -> Log in -> Sign up: 5
# Log in -> Homepage -> Resources center -> Other: 4
# Sign up -> Log in -> Checkout -> Pricing: 4
# Sign up -> Log in -> Other -> Homepage: 4
# Homepage -> Pricing -> Homepage -> Career track certificate: 4
# Pricing -> Homepage -> Other -> Homepage: 4
# Career tracks -> Homepage -> Sign up -> Log in: 4
# Resources center -> Homepage -> Pricing -> Checkout: 4
# Pricing -> Courses -> Log in -> Checkout: 4
# Courses -> Sign up -> Log in -> Other: 4
# Log in -> Other -> Coupon -> Coupon: 4
# Log in -> Checkout -> Sign up -> Log in: 4
# Resources center -> Log in -> Resources center -> Log in: 4
# Log in -> Coupon -> Courses -> Sign up: 4
# Log in -> Homepage -> Pricing -> Career tracks: 4
# Career track certificate -> Homepage -> Log in -> Homepage: 4
# Homepage -> Pricing -> Coupon -> Other: 4
# Homepage -> Career track certificate -> Career tracks -> Homepage: 4
# Homepage -> Course certificate -> Career track certificate -> Career tracks: 4
# Upcoming courses -> Courses -> Sign up -> Log in: 4
# Courses -> Sign up -> Log in -> Sign up: 4
# Pricing -> Sign up -> Log in -> Other: 4
# Homepage -> Log in -> Other -> Coupon: 4
# Log in -> Other -> Log in -> Courses: 4
# Career track certificate -> Homepage -> Career track certificate -> Career tracks: 4
# Sign up -> Homepage -> Pricing -> Career track certificate: 4
# Log in -> Homepage -> Courses -> Sign up: 4
# Sign up -> Coupon -> Checkout -> Log in: 4
# Log in -> Resources center -> Log in -> Resources center: 4
# Resources center -> Log in -> Resources center -> Other: 4
# Sign up -> Resources center -> Other -> Resources center: 4
# Coupon -> Homepage -> Career tracks -> Courses: 4
# Career track certificate -> Career tracks -> Career track certificate -> Pricing: 4
# Pricing -> Log in -> Other -> Log in: 4
# Log in -> Coupon -> Log in -> Homepage: 4
# Homepage -> Log in -> Courses -> Sign up: 4
# Checkout -> Other -> Courses -> Sign up: 4
# Career tracks -> Homepage -> Career track certificate -> Career tracks: 4
# Log in -> Courses -> Log in -> Checkout: 4
# Sign up -> Pricing -> Checkout -> Homepage: 4
# Checkout -> Coupon -> Checkout -> Coupon: 4
# Sign up -> Log in -> Coupon -> Log in: 4
# Career tracks -> Coupon -> Homepage -> Log in: 4
# Homepage -> Career track certificate -> Sign up -> Homepage: 4
# Homepage -> Courses -> Log in -> Other: 4
# Other -> Pricing -> Checkout -> Homepage: 4
# Homepage -> Pricing -> Homepage -> Other: 4
# Other -> Homepage -> Log in -> Coupon: 4
# Pricing -> Homepage -> Pricing -> Sign up: 4
# Sign up -> Log in -> Courses -> Log in: 4
# Log in -> Checkout -> Log in -> Coupon: 4
# Coupon -> Other -> Homepage -> Sign up: 4
# Log in -> Homepage -> Career track certificate -> Homepage: 4
# Other -> Courses -> Sign up -> Courses: 4
# Sign up -> Checkout -> Coupon -> Log in: 4
# Pricing -> Career tracks -> Sign up -> Log in: 4
# Resources center -> Log in -> Homepage -> Log in: 4
# Homepage -> Log in -> Homepage -> Resources center: 4
# Courses -> Sign up -> Checkout -> Career tracks: 4
# Sign up -> Checkout -> Career tracks -> Sign up: 4
# Homepage -> Log in -> Coupon -> Coupon: 4
# Coupon -> Log in -> Other -> Log in: 4
# Checkout -> Log in -> Pricing -> Log in: 4
# Homepage -> Courses -> Coupon -> Homepage: 4
# Sign up -> Coupon -> Other -> Homepage: 4
# Other -> Homepage -> Pricing -> Checkout: 4
# Homepage -> Career tracks -> Log in -> Other: 4
# Log in -> Other -> Sign up -> Homepage: 4
# Other -> Homepage -> Career tracks -> Homepage: 4
# Career tracks -> Homepage -> Career tracks -> Other: 4
# Career tracks -> Courses -> Career tracks -> Other: 4
# Sign up -> Log in -> Courses -> Sign up: 4
# Checkout -> Other -> Homepage -> Sign up: 4
# Pricing -> Checkout -> Log in -> Homepage: 4
# Homepage -> Resources center -> Homepage -> Resources center: 4
# Resources center -> Other -> Log in -> Homepage: 4
# Log in -> Homepage -> Pricing -> Resources center: 4
# Other -> Resources center -> Homepage -> Log in: 4
# Homepage -> Log in -> Checkout -> Career tracks: 4
# Log in -> Checkout -> Career tracks -> Courses: 4
# Pricing -> Courses -> Career tracks -> Sign up: 4
# Pricing -> Homepage -> Career tracks -> Homepage: 4
# Homepage -> Pricing -> Sign up -> Coupon: 4
# Pricing -> Sign up -> Coupon -> Other: 4
# Homepage -> Pricing -> Career track certificate -> Career tracks: 4
# Career tracks -> Log in -> Checkout -> Homepage: 4
# Courses -> Homepage -> Courses -> Sign up: 4
# Pricing -> Courses -> Log in -> Homepage: 4
# Career track certificate -> Sign up -> Career track certificate -> Sign up: 4
# Homepage -> Career tracks -> Homepage -> Log in: 4
# Career track certificate -> Pricing -> Checkout -> Homepage: 4
# Log in -> Sign up -> Homepage -> Pricing: 4
# Courses -> Career tracks -> Career track certificate -> Pricing: 4
# Career track certificate -> Career tracks -> Log in -> Homepage: 4
# Sign up -> Checkout -> Coupon -> Other: 4
# Coupon -> Checkout -> Other -> Log in: 4
# Checkout -> Homepage -> Pricing -> Career track certificate: 4
# Homepage -> Pricing -> Career track certificate -> Course certificate: 4
# Log in -> Homepage -> Course certificate -> Homepage: 4
# Checkout -> Resources center -> Other -> Resources center: 4
# Courses -> Sign up -> Other -> Log in: 4
# Sign up -> Other -> Log in -> Coupon: 4
# Coupon -> Homepage -> Sign up -> Other: 4
# Homepage -> Course certificate -> Career track certificate -> Courses: 4
# Coupon -> Homepage -> Courses -> Coupon: 4
# Career tracks -> Pricing -> Sign up -> Homepage: 4
# Checkout -> Other -> Log in -> Resources center: 4
# Pricing -> Log in -> Checkout -> Other: 4
# Log in -> Other -> Log in -> Sign up: 4
# Courses -> Homepage -> Log in -> Homepage: 4
# Career tracks -> Pricing -> Career tracks -> Sign up: 4
# Log in -> Checkout -> Career tracks -> Sign up: 4
# Homepage -> Pricing -> Log in -> Other: 4
# Log in -> Resources center -> Other -> Log in: 4
# Sign up -> Homepage -> Sign up -> Other: 4
# Other -> Checkout -> Log in -> Checkout: 4
# Sign up -> Courses -> Sign up -> Courses: 4
# Pricing -> Checkout -> Other -> Coupon: 4
# Coupon -> Courses -> Sign up -> Log in: 4
# Homepage -> Sign up -> Homepage -> Resources center: 4
# Checkout -> Pricing -> Sign up -> Checkout: 4
# Sign up -> Checkout -> Homepage -> Course certificate: 4
# Courses -> Career tracks -> Career track certificate -> Career tracks: 4
# Checkout -> Pricing -> Sign up -> Homepage: 4
# Upcoming courses -> Career tracks -> Courses -> Homepage: 4
# Log in -> Other -> Other -> Homepage: 4
# Coupon -> Other -> Log in -> Other: 4
# Homepage -> Sign up -> Coupon -> Checkout: 4
# Courses -> Career tracks -> Upcoming courses -> Courses: 4
# Career tracks -> Upcoming courses -> Courses -> Sign up: 4
# Log in -> Homepage -> Log in -> Resources center: 4
# Homepage -> Pricing -> Resources center -> Courses: 4
# Pricing -> Log in -> Checkout -> Pricing: 4
# Other -> Homepage -> Courses -> Career tracks: 4
# Other -> Homepage -> Courses -> Sign up: 4
# Pricing -> Career track certificate -> Sign up -> Career track certificate: 4
# Other -> Homepage -> Log in -> Sign up: 4
# Courses -> Pricing -> Homepage -> Pricing: 4
# Sign up -> Career tracks -> Log in -> Checkout: 4
# Homepage -> Courses -> Pricing -> Checkout: 4
# Courses -> Pricing -> Checkout -> Courses: 4
# Checkout -> Pricing -> Courses -> Homepage: 4
# Homepage -> Course certificate -> Sign up -> Homepage: 4
# Sign up -> Homepage -> Courses -> Sign up: 4
# Courses -> Homepage -> Log in -> Coupon: 4
# Log in -> Courses -> Sign up -> Courses: 4
# Career track certificate -> Career tracks -> Courses -> Pricing: 4
# Coupon -> Coupon -> Courses -> Sign up: 4
# Checkout -> Homepage -> Courses -> Other: 4
# Career tracks -> Log in -> Checkout -> Other: 4
# Checkout -> Courses -> Sign up -> Homepage: 4
# Courses -> Career track certificate -> Coupon -> Homepage: 4
# Homepage -> Sign up -> Checkout -> Log in: 4
# Sign up -> Checkout -> Log in -> Homepage: 4
# Pricing -> Career track certificate -> Sign up -> Log in: 4
# Career track certificate -> Sign up -> Homepage -> Sign up: 4
# Sign up -> Pricing -> Checkout -> Coupon: 4
# Pricing -> Other -> Pricing -> Checkout: 4
# Courses -> Pricing -> Homepage -> Courses: 4
# Checkout -> Log in -> Checkout -> Career tracks: 4
# Courses -> Sign up -> Courses -> Career tracks: 4
# Checkout -> Homepage -> Sign up -> Coupon: 4
# Sign up -> Coupon -> Homepage -> Course certificate: 4
# Sign up -> Checkout -> Other -> Sign up: 4
# Career tracks -> Sign up -> Career tracks -> Career track certificate: 4
# Courses -> Career tracks -> Homepage -> Courses: 4
# Homepage -> Career tracks -> Pricing -> Homepage: 4
# Career tracks -> Courses -> Pricing -> Career track certificate: 4
# Career tracks -> Courses -> Homepage -> Sign up: 4
# Homepage -> Sign up -> Homepage -> Career track certificate: 4
# Sign up -> Courses -> Career tracks -> Courses: 4
# Courses -> Homepage -> Sign up -> Coupon: 4
# Career track certificate -> Sign up -> Career track certificate -> Pricing: 4
# Career tracks -> Courses -> Pricing -> Career tracks: 4
# Career tracks -> Homepage -> Sign up -> Checkout: 4
# Pricing -> Homepage -> Courses -> Homepage: 4
# Pricing -> Courses -> Career tracks -> Homepage: 4
# Homepage -> Career tracks -> Pricing -> Sign up: 4
# Log in -> Pricing -> Log in -> Checkout: 4
# Career tracks -> Courses -> Career track certificate -> Career tracks: 4
# Pricing -> Checkout -> Coupon -> Coupon: 4
# Coupon -> Coupon -> Coupon -> Other: 4
# Coupon -> Coupon -> Other -> Pricing: 4
# Courses -> Career tracks -> Courses -> Coupon: 4
# Blog -> Other -> Blog -> Other: 4
# Sign up -> Checkout -> Coupon -> Coupon: 4
# Courses -> Sign up -> Checkout -> Log in: 4
# Homepage -> Pricing -> Sign up -> Pricing: 4
# Other -> Blog -> Other -> Blog: 4
# Checkout -> Sign up -> Checkout -> Homepage: 4
# Sign up -> Log in -> Homepage -> Resources center: 3
# Other -> Homepage -> Career tracks -> Courses: 3
# Log in -> Checkout -> Checkout -> Homepage: 3
# Career track certificate -> Career tracks -> Courses -> Coupon: 3
# Checkout -> Coupon -> Log in -> Homepage: 3
# Coupon -> Homepage -> Pricing -> Career tracks: 3
# Sign up -> Homepage -> Pricing -> Coupon: 3
# Coupon -> Pricing -> Checkout -> Pricing: 3
# Courses -> Log in -> Checkout -> Courses: 3
# Checkout -> Courses -> Sign up -> Log in: 3
# Homepage -> Log in -> Checkout -> Resources center: 3
# Log in -> Resources center -> Log in -> Other: 3
# Log in -> Homepage -> Career track certificate -> Career tracks: 3
# Checkout -> Homepage -> Pricing -> Coupon: 3
# Pricing -> Coupon -> Other -> Log in: 3
# Coupon -> Coupon -> Pricing -> Checkout: 3
# Coupon -> Pricing -> Checkout -> Homepage: 3
# Homepage -> Sign up -> Homepage -> Course certificate: 3
# Homepage -> Career track certificate -> Other -> Log in: 3
# Pricing -> Checkout -> Pricing -> Upcoming courses: 3
# Pricing -> Checkout -> Other -> Pricing: 3
# Log in -> Courses -> Sign up -> Log in: 3
# Coupon -> Homepage -> Career tracks -> Coupon: 3
# Resources center -> Courses -> Resources center -> Courses: 3
# Checkout -> Coupon -> Log in -> Coupon: 3
# Resources center -> Other -> Sign up -> Homepage: 3
# Pricing -> Career track certificate -> Homepage -> Pricing: 3
# Courses -> Homepage -> Log in -> Other: 3
# Homepage -> Log in -> Other -> Resources center: 3
# Log in -> Other -> Resources center -> Log in: 3
# Log in -> Other -> Pricing -> Log in: 3
# Career tracks -> Career track certificate -> Pricing -> Checkout: 3
# Career track certificate -> Pricing -> Checkout -> Pricing: 3
# Pricing -> Resources center -> Other -> Log in: 3
# Checkout -> Homepage -> Course certificate -> Courses: 3
# Log in -> Courses -> Sign up -> Homepage: 3
# Pricing -> Sign up -> Pricing -> Courses: 3
# Sign up -> Career tracks -> Sign up -> Career tracks: 3
# Sign up -> Checkout -> Other -> Courses: 3
# Other -> Courses -> Sign up -> Log in: 3
# Courses -> Log in -> Checkout -> Coupon: 3
# Resources center -> Other -> Resources center -> Log in: 3
# Pricing -> Career track certificate -> Career tracks -> Sign up: 3
# Other -> Resources center -> Other -> Sign up: 3
# Other -> Resources center -> Other -> Coupon: 3
# Other -> Coupon -> Checkout -> Coupon: 3
# Homepage -> Courses -> Upcoming courses -> Courses: 3
# Courses -> Log in -> Homepage -> Sign up: 3
# Courses -> Log in -> Other -> Coupon: 3
# Coupon -> Coupon -> Other -> Homepage: 3
# Sign up -> Homepage -> Career tracks -> Pricing: 3
# Checkout -> Pricing -> Log in -> Homepage: 3
# Homepage -> Pricing -> Career tracks -> Pricing: 3
# Sign up -> Homepage -> Log in -> Pricing: 3
# Checkout -> Log in -> Other -> Homepage: 3
# Checkout -> Log in -> Coupon -> Log in: 3
# Sign up -> Other -> Sign up -> Log in: 3
# Log in -> Coupon -> Log in -> Other: 3
# Homepage -> Resources center -> Other -> Courses: 3
# Resources center -> Other -> Courses -> Sign up: 3
# Other -> Resources center -> Other -> Courses: 3
# Log in -> Resources center -> Other -> Homepage: 3
# Career tracks -> Resources center -> Other -> Resources center: 3
# Homepage -> Courses -> Log in -> Courses: 3
# Log in -> Courses -> Sign up -> Checkout: 3
# Other -> Log in -> Resources center -> Log in: 3
# Checkout -> Homepage -> Courses -> Coupon: 3
# Log in -> Checkout -> Coupon -> Pricing: 3
# Log in -> Homepage -> Sign up -> Coupon: 3
# Courses -> Upcoming courses -> Courses -> Sign up: 3
# Courses -> Upcoming courses -> Courses -> Homepage: 3
# Homepage -> Courses -> Career tracks -> Career track certificate: 3
# Courses -> Career tracks -> Career track certificate -> Course certificate: 3
# Other -> Log in -> Homepage -> Career tracks: 3
# Homepage -> Career tracks -> Log in -> Homepage: 3
# Homepage -> Career tracks -> Courses -> Pricing: 3
# Career tracks -> Pricing -> Homepage -> Career tracks: 3
# Homepage -> Pricing -> Resources center -> Career track certificate: 3
# Courses -> Career tracks -> Homepage -> Career tracks: 3
# Career tracks -> Homepage -> Career tracks -> Resources center: 3
# Courses -> Log in -> Courses -> Pricing: 3
# Courses -> Career tracks -> Pricing -> Career tracks: 3
# Homepage -> Career tracks -> Homepage -> Coupon: 3
# Sign up -> Homepage -> Career track certificate -> Pricing: 3
# Homepage -> Career track certificate -> Pricing -> Career track certificate: 3
# Coupon -> Homepage -> Career track certificate -> Pricing: 3
# Homepage -> Career track certificate -> Pricing -> Courses: 3
# Pricing -> Courses -> Career tracks -> Pricing: 3
# Pricing -> Checkout -> Pricing -> Other: 3
# Other -> Homepage -> Pricing -> Career track certificate: 3
# Homepage -> Career track certificate -> Sign up -> Coupon: 3
# Career tracks -> Courses -> Homepage -> Resources center: 3
# Courses -> Career tracks -> Courses -> Career track certificate: 3
# Career track certificate -> Sign up -> Log in -> Checkout: 3
# Sign up -> Coupon -> Homepage -> Pricing: 3
# Checkout -> Log in -> Homepage -> Pricing: 3
# Other -> Coupon -> Homepage -> Career tracks: 3
# Courses -> Pricing -> Sign up -> Pricing: 3
# Checkout -> Career tracks -> Courses -> Career tracks: 3
# Other -> Homepage -> Career tracks -> Sign up: 3
# Checkout -> Pricing -> Career tracks -> Sign up: 3
# Career tracks -> Courses -> Log in -> Coupon: 3
# Coupon -> Other -> Homepage -> Career track certificate: 3
# Log in -> Checkout -> Courses -> Other: 3
# Courses -> Pricing -> Courses -> Log in: 3
# Course certificate -> Career track certificate -> Sign up -> Career track certificate: 3
# Other -> Career tracks -> Courses -> Sign up: 3
# Checkout -> Pricing -> Homepage -> Pricing: 3
# Career tracks -> Career track certificate -> Sign up -> Career track certificate: 3
# Sign up -> Courses -> Pricing -> Courses: 3
# Homepage -> Career track certificate -> Log in -> Homepage: 3
# Checkout -> Homepage -> Sign up -> Courses: 3
# Upcoming courses -> Career tracks -> Sign up -> Career tracks: 3
# Career track certificate -> Career tracks -> Homepage -> Pricing: 3
# Courses -> Homepage -> Career track certificate -> Pricing: 3
# Log in -> Checkout -> Career track certificate -> Sign up: 3
# Checkout -> Career track certificate -> Sign up -> Homepage: 3
# Sign up -> Homepage -> Career track certificate -> Career tracks: 3
# Career tracks -> Courses -> Pricing -> Homepage: 3
# Career tracks -> Homepage -> Courses -> Homepage: 3
# Career track certificate -> Course certificate -> Career track certificate -> Career tracks: 3
# Log in -> Sign up -> Homepage -> Courses: 3
# Log in -> Checkout -> Resources center -> Other: 3
# Homepage -> Sign up -> Other -> Homepage: 3
# Checkout -> Homepage -> Other -> Log in: 3
# Sign up -> Homepage -> Pricing -> Courses: 3
# Log in -> Coupon -> Other -> Courses: 3
# Career tracks -> Sign up -> Log in -> Sign up: 3
# Courses -> Log in -> Homepage -> Courses: 3
# Pricing -> Courses -> Career track certificate -> Courses: 3
# Courses -> Career tracks -> Log in -> Other: 3
# Log in -> Other -> Coupon -> Other: 3
# Coupon -> Other -> Courses -> Sign up: 3
# Courses -> Career tracks -> Homepage -> Log in: 3
# Course certificate -> Pricing -> Checkout -> Pricing: 3
# Sign up -> Other -> Log in -> Other: 3
# Homepage -> Other -> Log in -> Homepage: 3
# Checkout -> Other -> Resources center -> Other: 3
# Log in -> Homepage -> Pricing -> Coupon: 3
# Pricing -> Coupon -> Homepage -> Pricing: 3
# Course certificate -> Log in -> Homepage -> Log in: 3
# Log in -> Homepage -> Log in -> Career track certificate: 3
# Homepage -> Course certificate -> Pricing -> Courses: 3
# Log in -> Checkout -> Courses -> Pricing: 3
# Pricing -> Log in -> Checkout -> Coupon: 3
# Coupon -> Homepage -> Pricing -> Log in: 3
# Homepage -> Career tracks -> Coupon -> Checkout: 3
# Log in -> Coupon -> Other -> Homepage: 3
# Career tracks -> Sign up -> Other -> Homepage: 3
# Other -> Log in -> Other -> Other: 3
# Other -> Sign up -> Log in -> Sign up: 3
# Course certificate -> Courses -> Upcoming courses -> Courses: 3
# Log in -> Homepage -> Pricing -> Career track certificate: 3
# Pricing -> Career track certificate -> Course certificate -> Courses: 3
# Sign up -> Checkout -> Sign up -> Log in: 3
# Other -> Homepage -> Career tracks -> Log in: 3
# Career tracks -> Log in -> Other -> Resources center: 3
# Other -> Resources center -> Other -> Success stories: 3
# Pricing -> Homepage -> Pricing -> Courses: 3
# Resources center -> Other -> Sign up -> Log in: 3
# Other -> Coupon -> Other -> Log in: 3
# Courses -> Sign up -> Courses -> Homepage: 3
# Other -> Coupon -> Courses -> Sign up: 3
# Coupon -> Other -> Checkout -> Log in: 3
# Other -> Coupon -> Checkout -> Other: 3
# Career tracks -> Sign up -> Other -> Log in: 3
# Sign up -> Pricing -> Checkout -> Pricing: 3
# Log in -> Homepage -> Sign up -> Pricing: 3
# Sign up -> Homepage -> Sign up -> Coupon: 3
# Sign up -> Courses -> Sign up -> Homepage: 3
# Homepage -> Career tracks -> Resources center -> Other: 3
# Pricing -> Coupon -> Homepage -> Courses: 3
# Career tracks -> Courses -> Sign up -> Other: 3
# Courses -> Log in -> Checkout -> Log in: 3
# Log in -> Homepage -> Resources center -> Homepage: 3
# Courses -> Sign up -> Coupon -> Other: 3
# Checkout -> Pricing -> Courses -> Career tracks: 3
# Log in -> Other -> Homepage -> Courses: 3
# Log in -> Coupon -> Other -> Sign up: 3
# Other -> Sign up -> Log in -> Other: 3
# Career tracks -> Homepage -> Career tracks -> Coupon: 3
# Homepage -> Pricing -> Checkout -> Courses: 3
# Checkout -> Courses -> Pricing -> Checkout: 3
# Courses -> Pricing -> Checkout -> Log in: 3
# Coupon -> Sign up -> Log in -> Homepage: 3
# Pricing -> Checkout -> Other -> Log in: 3
# Homepage -> Log in -> Sign up -> Homepage: 3
# Checkout -> Pricing -> Checkout -> Log in: 3
# Checkout -> Other -> Courses -> Homepage: 3
# Pricing -> Checkout -> Pricing -> Resources center: 3
# Checkout -> Pricing -> Resources center -> Pricing: 3
# Career tracks -> Sign up -> Career tracks -> Log in: 3
# Other -> Other -> Homepage -> Courses: 3
# Other -> Homepage -> Courses -> Pricing: 3
# Courses -> Log in -> Coupon -> Log in: 3
# Log in -> Homepage -> Courses -> Pricing: 3
# Pricing -> Courses -> Sign up -> Homepage: 3
# ...
# Courses -> Instructors -> Courses -> Instructors: 1
# Instructors -> Courses -> Instructors -> Courses: 1
# Courses -> Instructors -> Courses -> Career tracks: 1
# Instructors -> Courses -> Career tracks -> Courses: 1
# Resources center -> Other -> Courses -> Blog: 1
# Other -> Courses -> Blog -> Courses: 1
# Courses -> Blog -> Courses -> Career tracks: 1
# Blog -> Courses -> Career tracks -> Courses: 1
# Courses -> Career tracks -> Courses -> Success stories: 1
# Career tracks -> Courses -> Success stories -> Other: 1
# Courses -> Success stories -> Other -> Sign up: 1
# Success stories -> Other -> Sign up -> Homepage: 1
# Career tracks -> Pricing -> Career track certificate -> Sign up: 1
# Sign up -> Career track certificate -> Courses -> Career tracks: 1
# Career tracks -> Courses -> Upcoming courses -> Course certificate: 1
# Courses -> Upcoming courses -> Course certificate -> Pricing: 1
# Course certificate -> Pricing -> Courses -> Career tracks: 1
# Courses -> Pricing -> Resources center -> Other: 1
# Pricing -> Resources center -> Other -> Courses: 1
# Other -> Courses -> Sign up -> Homepage: 1
# Courses -> Sign up -> Homepage -> Course certificate: 1
# Sign up -> Homepage -> Course certificate -> Resources center: 1
# Homepage -> Course certificate -> Resources center -> Other: 1
# Course certificate -> Resources center -> Other -> Resources center: 1
# Homepage -> Career tracks -> Log in -> Courses: 1
# Other -> Resources center -> Courses -> Log in: 1
# Resources center -> Courses -> Log in -> Checkout: 1
# Other -> Other -> Pricing -> Other: 1
# Other -> Pricing -> Other -> Career track certificate: 1
# Pricing -> Other -> Career track certificate -> Course certificate: 1
# Other -> Career track certificate -> Course certificate -> Resources center: 1
# Career track certificate -> Course certificate -> Resources center -> Course certificate: 1
# Course certificate -> Resources center -> Course certificate -> Resources center: 1
# Resources center -> Course certificate -> Resources center -> Pricing: 1
# Course certificate -> Resources center -> Pricing -> Checkout: 1
# Resources center -> Pricing -> Resources center -> Course certificate: 1
# Resources center -> Course certificate -> Homepage -> Career track certificate: 1
# Course certificate -> Homepage -> Career track certificate -> Course certificate: 1
# Career track certificate -> Course certificate -> Sign up -> Checkout: 1
# Course certificate -> Sign up -> Checkout -> Other: 1
# Courses -> Sign up -> Courses -> Other: 1
# Sign up -> Courses -> Other -> Courses: 1
# Courses -> Other -> Courses -> Sign up: 1
# Homepage -> Courses -> Career tracks -> Pricing: 1
# Courses -> Career tracks -> Pricing -> Other: 1
# Pricing -> Other -> Pricing -> Career track certificate: 1
# Other -> Pricing -> Career track certificate -> Homepage: 1
# Career track certificate -> Homepage -> Career tracks -> Success stories: 1
# Homepage -> Career tracks -> Success stories -> Resources center: 1
# Career tracks -> Success stories -> Resources center -> Other: 1
# Success stories -> Resources center -> Other -> Courses: 1
# Resources center -> Other -> Courses -> Upcoming courses: 1
# Other -> Courses -> Upcoming courses -> Course certificate: 1
# Courses -> Upcoming courses -> Course certificate -> Career tracks: 1
# Upcoming courses -> Course certificate -> Career tracks -> Sign up: 1
# Course certificate -> Career tracks -> Sign up -> Checkout: 1
# Other -> Homepage -> Career tracks -> Pricing: 1
# Career tracks -> Pricing -> Courses -> Homepage: 1
# Pricing -> Courses -> Homepage -> Other: 1
# Homepage -> Other -> Success stories -> Homepage: 1
# Other -> Success stories -> Homepage -> Career tracks: 1
# Success stories -> Homepage -> Career tracks -> Sign up: 1
# Pricing -> Sign up -> Pricing -> Other: 1
# Sign up -> Pricing -> Other -> Pricing: 1
# Homepage -> Career tracks -> Courses -> Other: 1
# Career tracks -> Courses -> Other -> Coupon: 1
# Courses -> Other -> Coupon -> Other: 1
# Other -> Coupon -> Other -> Other: 1
# Sign up -> Course certificate -> Pricing -> Resources center: 1
# Course certificate -> Pricing -> Resources center -> Other: 1
# Pricing -> Resources center -> Other -> Resources center: 1
# Resources center -> Other -> Resources center -> Success stories: 1
# Other -> Resources center -> Success stories -> Log in: 1
# Success stories -> Log in -> Checkout -> Homepage: 1
# Other -> Resources center -> Homepage -> Sign up: 1
# Checkout -> Coupon -> Other -> Courses: 1
# Checkout -> Other -> Homepage -> Courses: 1
# Other -> Homepage -> Courses -> Resources center: 1
# Courses -> Resources center -> Homepage -> Career tracks: 1
# Resources center -> Homepage -> Career tracks -> Pricing: 1
# Career tracks -> Pricing -> Homepage -> Sign up: 1
# Coupon -> Homepage -> Pricing -> Other: 1
# Pricing -> Other -> Pricing -> Career tracks: 1
# Coupon -> Checkout -> Other -> About us: 1
# Checkout -> Other -> About us -> Checkout: 1
# Other -> About us -> Checkout -> Other: 1
# About us -> Checkout -> Other -> Sign up: 1
# Other -> Sign up -> Coupon -> Coupon: 1
# Other -> Homepage -> Pricing -> Other: 1
# Homepage -> Pricing -> Other -> Sign up: 1
# Pricing -> Other -> Sign up -> Other: 1
# Other -> Sign up -> Other -> Courses: 1
# Sign up -> Other -> Courses -> Success stories: 1
# Other -> Courses -> Success stories -> Resources center: 1
# Courses -> Success stories -> Resources center -> Other: 1
# Success stories -> Resources center -> Other -> Log in: 1
# Sign up -> Homepage -> Career tracks -> Career track certificate: 1
# Homepage -> Career tracks -> Career track certificate -> Resources center: 1
# Career tracks -> Career track certificate -> Resources center -> Success stories: 1
# Career track certificate -> Resources center -> Success stories -> Checkout: 1
# Resources center -> Success stories -> Checkout -> Success stories: 1
# Success stories -> Checkout -> Success stories -> Career tracks: 1
# Success stories -> Career tracks -> Courses -> Homepage: 1
# Sign up -> Career tracks -> Sign up -> Other: 1
# Career tracks -> Sign up -> Other -> Pricing: 1
# Sign up -> Other -> Pricing -> Sign up: 1
# Sign up -> Pricing -> Courses -> Career tracks: 1
# Pricing -> Courses -> Career tracks -> Coupon: 1
# Courses -> Career tracks -> Coupon -> Career tracks: 1
# Career tracks -> Coupon -> Career tracks -> Log in: 1
# Coupon -> Career tracks -> Log in -> Other: 1
# Career tracks -> Log in -> Other -> Coupon: 1
# Other -> Coupon -> Homepage -> Coupon: 1
# Coupon -> Homepage -> Coupon -> Homepage: 1
# Homepage -> Coupon -> Homepage -> Courses: 1
# Sign up -> Coupon -> Other -> Career tracks: 1
# Coupon -> Other -> Career tracks -> Other: 1
# Other -> Career tracks -> Other -> Sign up: 1
# Career tracks -> Other -> Sign up -> Other: 1
# Other -> Sign up -> Other -> Career tracks: 1
# Other -> Career tracks -> Sign up -> Career tracks: 1
# Sign up -> Other -> Log in -> Career track certificate: 1
# Other -> Log in -> Career track certificate -> Career tracks: 1
# Log in -> Career track certificate -> Career tracks -> Log in: 1
# Career track certificate -> Career tracks -> Log in -> Other: 1
# Other -> Coupon -> Log in -> Checkout: 1
# Career tracks -> Pricing -> Career tracks -> Other: 1
# Pricing -> Career tracks -> Other -> Homepage: 1
# Courses -> Homepage -> Coupon -> Checkout: 1
# Homepage -> Coupon -> Checkout -> Homepage: 1
# Career track certificate -> Career tracks -> Homepage -> Log in: 1
# Course certificate -> Career track certificate -> Courses -> Pricing: 1
# Career track certificate -> Courses -> Pricing -> Career track certificate: 1
# Courses -> Pricing -> Career track certificate -> Courses: 1
# Pricing -> Career track certificate -> Courses -> Success stories: 1
# Career track certificate -> Courses -> Success stories -> Career tracks: 1
# Courses -> Success stories -> Career tracks -> Sign up: 1
# Success stories -> Career tracks -> Sign up -> Checkout: 1
# Checkout -> Pricing -> Career track certificate -> Success stories: 1
# Pricing -> Career track certificate -> Success stories -> About us: 1
# Career track certificate -> Success stories -> About us -> Homepage: 1
# Success stories -> About us -> Homepage -> Coupon: 1
# About us -> Homepage -> Coupon -> Coupon: 1
# Homepage -> Coupon -> Coupon -> Other: 1
# Coupon -> Coupon -> Other -> Checkout: 1
# Coupon -> Other -> Checkout -> Other: 1
# Other -> Checkout -> Other -> Other: 1
# Other -> Other -> Sign up -> Homepage: 1
# Checkout -> Career track certificate -> Sign up -> Career track certificate: 1
# Sign up -> Career track certificate -> Sign up -> Checkout: 1
# Pricing -> Resources center -> Courses -> Log in: 1
# Resources center -> Courses -> Log in -> Sign up: 1
# Career track certificate -> Courses -> Log in -> Checkout: 1
# Homepage -> Career tracks -> Courses -> Checkout: 1
# Pricing -> Homepage -> Log in -> Sign up: 1
# Checkout -> Other -> Coupon -> Sign up: 1
# Coupon -> Sign up -> Homepage -> Other: 1
# Sign up -> Homepage -> Other -> Homepage: 1
# Course certificate -> Courses -> Career tracks -> Log in: 1
# Courses -> Career tracks -> Log in -> Sign up: 1
# Career tracks -> Log in -> Sign up -> Log in: 1
# Resources center -> Log in -> Checkout -> Resources center: 1
# Other -> Resources center -> Homepage -> Career tracks: 1
# Resources center -> Homepage -> Career tracks -> Resources center: 1
# Resources center -> Other -> Courses -> Coupon: 1
# Other -> Courses -> Coupon -> Sign up: 1
# Coupon -> Sign up -> Checkout -> Other: 1
# Courses -> Coupon -> Checkout -> Coupon: 1
# Other -> Coupon -> Log in -> Coupon: 1
# Coupon -> Homepage -> Courses -> Checkout: 1
# Homepage -> Courses -> Checkout -> Log in: 1
# Courses -> Checkout -> Log in -> Checkout: 1
# Other -> Homepage -> Course certificate -> Career track certificate: 1
# Course certificate -> Career track certificate -> Sign up -> Courses: 1
# Career track certificate -> Sign up -> Courses -> Career tracks: 1
# Checkout -> Homepage -> Other -> Course certificate: 1
# Homepage -> Other -> Course certificate -> Career track certificate: 1
# Other -> Course certificate -> Career track certificate -> Coupon: 1
# Course certificate -> Career track certificate -> Coupon -> Homepage: 1
# Career track certificate -> Coupon -> Homepage -> Resources center: 1
# Coupon -> Homepage -> Resources center -> Career tracks: 1
# Homepage -> Resources center -> Career tracks -> Courses: 1
# Resources center -> Career tracks -> Courses -> Log in: 1
# Log in -> Other -> Coupon -> Checkout: 1
# Coupon -> Homepage -> Career tracks -> Other: 1
# Career tracks -> Other -> Career tracks -> Instructors: 1
# Other -> Career tracks -> Instructors -> Courses: 1
# Career tracks -> Instructors -> Courses -> Sign up: 1
# Instructors -> Courses -> Sign up -> Homepage: 1
# Career tracks -> Sign up -> Homepage -> Resources center: 1
# Sign up -> Homepage -> Resources center -> Courses: 1
# Pricing -> Log in -> Sign up -> Other: 1
# Log in -> Sign up -> Other -> Other: 1
# Sign up -> Other -> Other -> Coupon: 1
# Other -> Other -> Coupon -> Pricing: 1
# Other -> Coupon -> Pricing -> Checkout: 1
# Courses -> Other -> Homepage -> Courses: 1
# Homepage -> Courses -> Pricing -> Course certificate: 1
# Pricing -> Course certificate -> Upcoming courses -> Courses: 1
# Course certificate -> Upcoming courses -> Courses -> Resources center: 1
# Upcoming courses -> Courses -> Resources center -> Other: 1
# Resources center -> Other -> Pricing -> Other: 1
# Other -> Pricing -> Other -> Upcoming courses: 1
# Pricing -> Other -> Upcoming courses -> Other: 1
# Other -> Upcoming courses -> Other -> Coupon: 1
# Upcoming courses -> Other -> Coupon -> Pricing: 1
# Other -> Coupon -> Pricing -> Log in: 1
# Coupon -> Pricing -> Log in -> Checkout: 1
# Other -> Sign up -> Other -> Homepage: 1
# Sign up -> Other -> Homepage -> Sign up: 1
# Other -> Homepage -> Sign up -> Other: 1
# Homepage -> Sign up -> Other -> Resources center: 1
# Resources center -> Other -> Success stories -> Sign up: 1
# Other -> Success stories -> Sign up -> Resources center: 1
# Success stories -> Sign up -> Resources center -> Coupon: 1
# Sign up -> Resources center -> Coupon -> Homepage: 1
# Resources center -> Coupon -> Homepage -> Career track certificate: 1
# Career track certificate -> Courses -> Career track certificate -> Resources center: 1
# Career track certificate -> Resources center -> Other -> Courses: 1
# Other -> Courses -> Homepage -> Career track certificate: 1
# Courses -> Homepage -> Career track certificate -> Course certificate: 1
# Career track certificate -> Course certificate -> Sign up -> Homepage: 1
# Checkout -> Other -> Career track certificate -> Courses: 1
# Other -> Career track certificate -> Courses -> Other: 1
# Courses -> Other -> Homepage -> Sign up: 1
# Other -> Coupon -> Other -> Course certificate: 1
# Coupon -> Other -> Course certificate -> Courses: 1
# Other -> Course certificate -> Courses -> Sign up: 1
# Course certificate -> Courses -> Sign up -> Coupon: 1
# Other -> Other -> Other -> Checkout: 1
# Other -> Checkout -> Other -> Checkout: 1
# Checkout -> Other -> Checkout -> Coupon: 1
# Pricing -> Career tracks -> Sign up -> Pricing: 1
# Sign up -> Pricing -> Checkout -> Career track certificate: 1
# Pricing -> Checkout -> Career track certificate -> Sign up: 1
# Other -> Pricing -> Other -> Homepage: 1
# Pricing -> Other -> Homepage -> Log in: 1
# Checkout -> Pricing -> Courses -> Career track certificate: 1
# Pricing -> Courses -> Career track certificate -> Course certificate: 1
# Courses -> Career track certificate -> Course certificate -> Pricing: 1
# Career track certificate -> Course certificate -> Pricing -> Homepage: 1
# Course certificate -> Pricing -> Homepage -> Pricing: 1
# Pricing -> Homepage -> Pricing -> Course certificate: 1
# Homepage -> Pricing -> Course certificate -> Homepage: 1
# Pricing -> Course certificate -> Homepage -> Sign up: 1
# Course certificate -> Homepage -> Sign up -> Log in: 1
# Coupon -> Homepage -> Log in -> Pricing: 1
# Log in -> Pricing -> Checkout -> Other: 1
# Checkout -> Other -> Other -> Career tracks: 1
# Other -> Other -> Career tracks -> Courses: 1
# Checkout -> Log in -> Homepage -> Resources center: 1
# Resources center -> Homepage -> Other -> Career tracks: 1
# Homepage -> Other -> Career tracks -> Sign up: 1
# Checkout -> Homepage -> Career tracks -> Log in: 1
# Resources center -> Checkout -> Coupon -> Checkout: 1
# Homepage -> Pricing -> Coupon -> Sign up: 1
# Pricing -> Coupon -> Sign up -> Homepage: 1
# Courses -> Resources center -> Career track certificate -> Homepage: 1
# Resources center -> Career track certificate -> Homepage -> Upcoming courses: 1
# Career track certificate -> Homepage -> Upcoming courses -> Homepage: 1
# Homepage -> Upcoming courses -> Homepage -> Upcoming courses: 1
# Upcoming courses -> Homepage -> Upcoming courses -> Course certificate: 1
# Homepage -> Upcoming courses -> Course certificate -> Career tracks: 1
# Upcoming courses -> Course certificate -> Career tracks -> Courses: 1
# Course certificate -> Career tracks -> Courses -> Homepage: 1
# Courses -> Coupon -> Homepage -> Pricing: 1
# Coupon -> Other -> Homepage -> Career tracks: 1
# Other -> Homepage -> Career tracks -> Coupon: 1
# Homepage -> Career track certificate -> Career tracks -> Other: 1
# Career track certificate -> Career tracks -> Other -> Career tracks: 1
# Career tracks -> Other -> Career tracks -> Pricing: 1
# Other -> Career tracks -> Pricing -> Homepage: 1
# Career tracks -> Coupon -> Coupon -> Coupon: 1
# Coupon -> Other -> Pricing -> Other: 1
# Log in -> Coupon -> Homepage -> About us: 1
# Coupon -> Homepage -> About us -> Other: 1
# Homepage -> About us -> Other -> Coupon: 1
# About us -> Other -> Coupon -> Coupon: 1
# Homepage -> Pricing -> Upcoming courses -> Coupon: 1
# Pricing -> Upcoming courses -> Coupon -> Coupon: 1
# Upcoming courses -> Coupon -> Coupon -> Homepage: 1
# Homepage -> Career tracks -> Other -> Pricing: 1
# Career tracks -> Other -> Pricing -> Career tracks: 1
# Other -> Pricing -> Career tracks -> Pricing: 1
# Pricing -> Career tracks -> Pricing -> Other: 1
# Career tracks -> Pricing -> Other -> Career tracks: 1
# Pricing -> Other -> Career tracks -> Courses: 1
# Other -> Coupon -> Homepage -> Upcoming courses: 1
# Coupon -> Homepage -> Upcoming courses -> Other: 1
# Homepage -> Upcoming courses -> Other -> Coupon: 1
# Upcoming courses -> Other -> Coupon -> Other: 1

# %% [markdown]
# ## Journey length is a metric that considers the average length of a user journey in terms of pages.

# %%
def user_journey_avg_length(data: pd.DataFrame) -> int:
    length = int(data["user_journey"].map(lambda x: len(x.split("-"))).mean())
    print(f'The average length of a user journey is {length} pages.')

user_journey_avg_length(all_subs)
# Out:
# The average length of a user journey is 10 pages.

# %% [markdown]
# # Recall, however, that the data provided also had a subscription plan column. A vital part of the analysis is finding patterns and differences between buyers’ behavior of different plans. For example, compare the journey of monthly users versus the one of annual users. This is why it’s essential to incorporate a plan parameter in these functions, allowing a data scientist to obtain the metrics for all subscription plans or any specific one.

# %%
all_subs
# Out:
#       user_id                                       user_journey  \
# 0        1516  Homepage-Log in-Other-Sign up-Log in-Homepage-...
# 1        3395  Other-Pricing-Sign up-Log in-Homepage-Pricing-...
# 2       10107  Homepage-Career tracks-Homepage-Career tracks-...
# 3       11145  Homepage-Log in-Homepage-Log in-Homepage-Log i...
# 4       12400  Homepage-Career tracks-Sign up-Log in-Other-Ca...
# ...       ...                                                ...
# 1345   509060                                              Other
# 1346   509061                                             Coupon
# 1347   509085                                             Coupon
# 1348   509095                                              Other
# 1349   509096                                       Other-Coupon
#
#      subscription_type
# 0               Annual
# 1               Annual
# 2               Annual
# 3              Monthly
# 4              Monthly
# ...                ...
# 1345            Annual
# 1346            Annual
# 1347            Annual
# 1348            Annual
# 1349            Annual
#
# [1350 rows x 3 columns]
